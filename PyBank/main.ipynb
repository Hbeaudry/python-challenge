# %%
# Import the pathlib and csv library
from pathlib import Path
import csv

# Set the file path
csvpath = Path('budget_data.csv')
output_text_file = Path('MainText.txt')

# Initialize variable to hold list_pnl and list_month
list_pnl = []
list_month = []

# Initialize line_num and net_change_list variable
line_num = 0

net_changes_list = []

# Open the input path as a file object
with open(csvpath, 'r') as csvfile:
    
    # Pass in the csv file to the csv.reader() function
    # (with ',' as the delmiter/separator) and return the csvreader object
    csvreader = csv.reader(csvfile, delimiter=',')
    

    # Go to the next row from the start of the file
    # (which is often the first row/header) and iterate line_num by 1
    header = next(csvreader)
    line_num += 1
    first_row = next(csvreader)
    prev_net = int(first_row[1])
    

    # Read each row of data after the header
    for row in csvreader:

        # Set pnl variable equal to the value in the 2nd column of each row
        # Set month variable equal to the value in the 1st column of each row
        pnl = int(row[1])
        month = (row[0])
        # Append the row pnl value to the list of list_pnl
        # Append the row month value to the list of list_month
        list_pnl.append(pnl)
        list_month.append(month)
        
        # track the net change
        net_changes = int(row[1]) - prev_net
        prev_net = int(row[1])
        net_changes_list = net_changes_list + [net_changes]

# print(net_changes_list)
# print(list_month)
# set variable average as the average change of profit
average = round(sum(net_changes_list) / len(net_changes_list), 2)
# print(average)

# set variable sum_pnl as the total
sum_pnl = sum(list_pnl) + int(first_row[1])

# set variable total_pnl as total number of months
total_pnl = len(list_pnl) + 1

# set variable greatest_increase as greatest increase in profits
greatest_increase = max(net_changes_list)
# print(greatest_increase)

# set variable greatest_decrease as greatest decrease in profits
greatest_decrease = min(net_changes_list)
# print(greatest_decrease)

# set variable greatest_month as the date of the greatest increase in profits
greatest_inc_position = net_changes_list.index(greatest_increase)
greatest_month = list_month[greatest_inc_position]
# print(greatest_month)

# set variable greatest_dec_month as the date of the greatest decrease in profits
greatest_dec_position = net_changes_list.index(greatest_decrease)
greatest_dec_month = list_month[greatest_dec_position]
# print(greatest_dec_month)


print('Financial Analysis')
print('----------------------------')
print(f'Total Months: {total_pnl}')
print(f'Total: ${sum_pnl}')
print(f'Average Change: ${average}')
print(f'Greatest Increase in Profits: {greatest_month} (${greatest_increase})')
print(f'Greatest Decrease in Profits: {greatest_dec_month} (${greatest_decrease})')


# Export Financial Analysis Results to MainText.txt
with open(output_text_file, "w") as MainText:
    MainText.write('Financial Analysis\n')
    MainText.write('----------------------------\n')
    MainText.write(f'Total Months: {total_pnl}\n')
    MainText.write(f'Total: ${sum_pnl}\n')
    MainText.write(f'Average Change: ${average}\n')
    MainText.write(f'Greatest Increase in Profits: {greatest_month} (${greatest_increase})\n')
    MainText.write(f'Greatest Decrease in Profits: {greatest_dec_month} (${greatest_decrease})\n')
# Out:
# Financial Analysis
# ----------------------------
# Total Months: 86
# Total: $38382578
# Average Change: $-2315.12
# Greatest Increase in Profits: Feb-2012 ($1926159)
# Greatest Decrease in Profits: Sep-2013 ($-2196167)
